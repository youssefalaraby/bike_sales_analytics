# %%
import pandas as pd

# %%
df1=pd.read_csv('bike_share_yr_0.csv')
df2=pd.read_csv('bike_share_yr_1.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17290 entries, 0 to 17289
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      17290 non-null  object
#  1   season      17290 non-null  int64
#  2   yr          17290 non-null  int64
#  3   mnth        17290 non-null  int64
#  4   hr          17290 non-null  int64
#  5   holiday     17290 non-null  int64
#  6   weekday     17290 non-null  int64
#  7   workingday  17290 non-null  int64
#  8   weathersit  17290 non-null  int64
#  9   temp        17290 non-null  float64
#  10  atemp       17290 non-null  float64
#  11  hum         17290 non-null  float64
#  12  windspeed   17290 non-null  float64
#  13  rider_type  17290 non-null  object
#  14  riders      17290 non-null  int64
# dtypes: float64(4), int64(9), object(2)
# memory usage: 2.0+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17468 entries, 0 to 17467
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      17468 non-null  object
#  1   season      17468 non-null  int64
#  2   yr          17468 non-null  int64
#  3   mnth        17468 non-null  int64
#  4   hr          17468 non-null  int64
#  5   holiday     17468 non-null  int64
#  6   weekday     17468 non-null  int64
#  7   workingday  17468 non-null  int64
#  8   weathersit  17468 non-null  int64
#  9   temp        17468 non-null  float64
#  10  atemp       17468 non-null  float64
#  11  hum         17468 non-null  float64
#  12  windspeed   17468 non-null  float64
#  13  rider_type  17468 non-null  object
#  14  riders      17468 non-null  int64
# dtypes: float64(4), int64(9), object(2)
# memory usage: 2.0+ MB

# %%
missing = df1.isnull().sum().sort_values(ascending=False)
print(missing)
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# rider_type    0
# riders        0
# dtype: int64

# %%
missing = df2.isnull().sum().sort_values(ascending=False)
print(missing)
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# rider_type    0
# riders        0
# dtype: int64

# %%
duplicates = df1.duplicated().sum()
print(f"Total duplicates: {duplicates}")
# Out:
# Total duplicates: 0

# %%
duplicates = df2.duplicated().sum()
print(f"Total duplicates: {duplicates}")
# Out:
# Total duplicates: 0

# %%
categorical_cols = ['season', 'holiday', 'weekday', 'workingday', 'weathersit', 'rider_type']

for col in categorical_cols:
    print(f"\n{col} unique values:")
    print(df1[col].unique())
# Out:
# season unique values:
# [1 2 3 4]
#
# holiday unique values:
# [0 1]
#
# weekday unique values:
# [6 0 1 2 3 4 5]
#
# workingday unique values:
# [0 1]
#
# weathersit unique values:
# [1 2 3 4]
#
# rider_type unique values:
# ['casual' 'registered']

# %%
categorical_cols = ['season', 'holiday', 'weekday', 'workingday', 'weathersit', 'rider_type']

for col in categorical_cols:
    print(f"\n{col} unique values:")
    print(df2[col].unique())
# Out:
# season unique values:
# [1 2 3 4]
#
# holiday unique values:
# [0 1]
#
# weekday unique values:
# [0 1 2 3 4 5 6]
#
# workingday unique values:
# [0 1]
#
# weathersit unique values:
# [1 2 3 4]
#
# rider_type unique values:
# ['casual' 'registered']

# %%
# If holiday = 1 → workingday should be 0
df1[(df1['holiday'] == 1) & (df1['workingday'] == 1)]
# Out:
# Empty DataFrame
# Columns: [dteday, season, yr, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, rider_type, riders]
# Index: []

# %%
# If holiday = 1 → workingday should be 0
df2[(df2['holiday'] == 1) & (df2['workingday'] == 1)]
# Out:
# Empty DataFrame
# Columns: [dteday, season, yr, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, rider_type, riders]
# Index: []

# %%
df1.head()
# Out:
#      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit
# 0  1/1/2021       1   0     1   0        0        6           0           1  \
# 1  1/1/2021       1   0     1   1        0        6           0           1
# 2  1/1/2021       1   0     1   2        0        6           0           1
# 3  1/1/2021       1   0     1   3        0        6           0           1
# 4  1/1/2021       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed rider_type  riders
# 0  0.24  0.2879  0.81        0.0     casual       3
# 1  0.22  0.2727  0.80        0.0     casual       8
# 2  0.22  0.2727  0.80        0.0     casual       5
# 3  0.24  0.2879  0.75        0.0     casual       3
# 4  0.24  0.2879  0.75        0.0     casual       0

# %%
df1['dteday'].unique()
# Out:
# array(['1/1/2021', '2/1/2021', '3/1/2021', '4/1/2021', '5/1/2021',
#        '6/1/2021', '7/1/2021', '8/1/2021', '9/1/2021', '10/1/2021',
#        '11/1/2021', '12/1/2021', '13/1/2021', '14/1/2021', '15/1/2021',
#        '16/1/2021', '17/1/2021', '18/1/2021', '19/1/2021', '20/1/2021',
#        '21/1/2021', '22/1/2021', '23/1/2021', '24/1/2021', '25/1/2021',
#        '26/1/2021', '27/1/2021', '28/1/2021', '29/1/2021', '30/1/2021',
#        '31/1/2021', '1/2/2021', '2/2/2021', '3/2/2021', '4/2/2021',
#        '5/2/2021', '6/2/2021', '7/2/2021', '8/2/2021', '9/2/2021',
#        '10/2/2021', '11/2/2021', '12/2/2021', '13/2/2021', '14/2/2021',
#        '15/2/2021', '16/2/2021', '17/2/2021', '18/2/2021', '19/2/2021',
#        '20/2/2021', '21/2/2021', '22/2/2021', '23/2/2021', '24/2/2021',
#        '25/2/2021', '26/2/2021', '27/2/2021', '28/2/2021', '1/3/2021',
#        '2/3/2021', '3/3/2021', '4/3/2021', '5/3/2021', '6/3/2021',
# ...

# %%
pd.to_datetime(df1['dteday'], errors='coerce')
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 17285          NaT
# 17286          NaT
# 17287          NaT
# 17288          NaT
# 17289          NaT
# Name: dteday, Length: 17290, dtype: datetime64[ns]

# %%
pd.to_datetime(df1['dteday'], format='%d/%m/%Y')
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 17285   2021-12-31
# 17286   2021-12-31
# 17287   2021-12-31
# 17288   2021-12-31
# 17289   2021-12-31
# Name: dteday, Length: 17290, dtype: datetime64[ns]
